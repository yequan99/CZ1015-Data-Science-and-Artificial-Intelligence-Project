# %%
# %run 1_Data_Cleaning.ipynb

# %% [markdown]
# ### Getting the dataset for Machine Learning portion

# %%
Clean_data_for_prediction = clean_df.copy()
Clean_data_for_prediction = Clean_data_for_prediction.drop(columns=['order_id', 'customer_id', 'customer_unique_id','payment_type', 'PurchasedYear'])
title = ['product_id','product_category_name_english', 'product_description_length', 'product_photos_qty', 
         'actual_hours','delivery_days','estimated', 'time_diff','price', 'freight_value', 'payment_value',
         'payment_installments','review_score']
Clean_data_for_prediction = Clean_data_for_prediction.reindex(columns = title)

# %%
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["product_category_name_english"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["product_description_length"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["product_photos_qty"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["actual_hours"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["delivery_days"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["time_diff"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["payment_value"].isnull() == False]
Clean_data_for_prediction = Clean_data_for_prediction[Clean_data_for_prediction["payment_installments"].isnull() == False]

# %%
Clean_data_for_prediction
# Out:
#                               product_id product_category_name_english  \
# 0       4244733e06e7ecb4970a6e2683c13e61                    cool_stuff
# 1       e5f2d52b802189ee658865ca93d83a8f                      pet_shop
# 2       c777355d18b72b67abbeef9df44fd0fd               furniture_decor
# 3       7634da152a4610f1595efa32f14722fc                     perfumery
# 4       ac6c3623068f30de03045865e4e10089                  garden_tools
# ...                                  ...                           ...
# 113317  4aa6014eceb682077f9dc4bffebc05b0                    housewares
# 113318  32e07fd915822b0765e448c4dd74c828         computers_accessories
# 113319  72a30483855e2eafc67aee5dc2560482                sports_leisure
# 113320  9c422a519119dcad7575db5af1ba540e         computers_accessories
# 113321  350688d9dc1e75ff97be326363655e01                bed_bath_table
#
#         product_description_length  product_photos_qty  actual_hours  \
# ...

# %% [markdown]
# ### Predicting Review Score

# %%
# Import train_test_split function
from sklearn.model_selection import train_test_split

# Import train_test_split function
from sklearn.model_selection import train_test_split

y = pd.DataFrame(Clean_data_for_prediction['review_score'].astype(int))  # Labels
X = pd.DataFrame(Clean_data_for_prediction[['product_description_length','actual_hours',
                                            'estimated', 'time_diff', 'product_photos_qty',
                                            'payment_installments']])  # Features

# Split dataset into training set and test set
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3) # 70% training and 30% test

# %%
#Import Random Forest Model
from sklearn.ensemble import RandomForestClassifier

#Create a Gaussian Classifier
clf=RandomForestClassifier(n_estimators=300)

#Train the model using the training sets y_pred=clf.predict(X_test)
clf.fit(X_train,y_train.values.ravel())

y_pred=clf.predict(X_test)

# %%
#Import scikit-learn metrics module for accuracy calculation
from sklearn import metrics
# Model Accuracy, how often is the classifier correct?
print("Accuracy:",metrics.accuracy_score(y_test, y_pred))
# Out:
# Accuracy: 0.6522083943387018

# %%
feature_imp = pd.Series(clf.feature_importances_,index=X_train.columns).sort_values(ascending=False)
feature_imp
# Out:
# time_diff                     0.228510
# product_description_length    0.226378
# actual_hours                  0.217022
# estimated                     0.200703
# payment_installments          0.068294
# product_photos_qty            0.059093
# dtype: float64

# %%
import matplotlib.pyplot as plt
# %matplotlib inline
# Creating a bar plot
sb.barplot(x=feature_imp, y=feature_imp.index)
# Add labels to your graph
plt.xlabel('Feature Importance Score')
plt.ylabel('Features')
plt.title("Visualizing Important Features")
plt.legend()
plt.show()
# Out:
# No handles with labels found to put in legend.
